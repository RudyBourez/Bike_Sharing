# %%
import pandas as pd
from pycaret.regression import setup, compare_models, create_model, tune_model

# %%
df = pd.read_csv("Datas/data_rudy.csv")

# %%
my_setup = setup(data = df, target="count",fold_shuffle=True)
# Out:
# <style type="text/css">
# #T_1a2e6_row42_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_1a2e6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1a2e6_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_1a2e6_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1a2e6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1a2e6_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_1a2e6_row0_col1" class="data row0 col1" >1552</td>
#     </tr>
#     <tr>
#       <th id="T_1a2e6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1a2e6_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_1a2e6_row1_col1" class="data row1 col1" >count</td>
#     </tr>
#     <tr>
#       <th id="T_1a2e6_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best_model = compare_models()
best_model
# Out:
# <style type="text/css">
# #T_95de6 th {
#   text-align: left;
# }
# ...

# %%
lightlgbm = create_model('lightgbm')
et = create_model('et')
rf = create_model('rf')
# Out:
# <style type="text/css">
# #T_f5e56_row10_col0, #T_f5e56_row10_col1, #T_f5e56_row10_col2, #T_f5e56_row10_col3, #T_f5e56_row10_col4, #T_f5e56_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_f5e56">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f5e56_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_f5e56_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_f5e56_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_f5e56_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_f5e56_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_f5e56_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f5e56_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f5e56_row0_col0" class="data row0 col0" >46.4623</td>
# ...

# %%
tunned_light = tune_model(lightlgbm)
tunned_rf = tune_model(rf)
tunned_et = tune_model(et)
# Out:
# <style type="text/css">
# #T_40f20_row10_col0, #T_40f20_row10_col1, #T_40f20_row10_col2, #T_40f20_row10_col3, #T_40f20_row10_col4, #T_40f20_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_40f20">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_40f20_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_40f20_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_40f20_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_40f20_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_40f20_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_40f20_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_40f20_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_40f20_row0_col0" class="data row0 col0" >51.9510</td>
# ...

# %%
tunned_et
# Out:
# ExtraTreesRegressor(bootstrap=False, ccp_alpha=0.0, criterion='mse',
#                     max_depth=10, max_features=1.0, max_leaf_nodes=None,
#                     max_samples=None, min_impurity_decrease=0.2,
#                     min_impurity_split=None, min_samples_leaf=5,
#                     min_samples_split=10, min_weight_fraction_leaf=0.0,
#                     n_estimators=290, n_jobs=-1, oob_score=False,
#                     random_state=1552, verbose=0, warm_start=False)

# %%
tunned_rf
# Out:
# RandomForestRegressor(bootstrap=False, ccp_alpha=0.0, criterion='mse',
#                       max_depth=10, max_features=1.0, max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.2,
#                       min_impurity_split=None, min_samples_leaf=5,
#                       min_samples_split=10, min_weight_fraction_leaf=0.0,
#                       n_estimators=290, n_jobs=-1, oob_score=False,
#                       random_state=1552, verbose=0, warm_start=False)

# %%
tunned_light
# Out:
# LGBMRegressor(bagging_fraction=0.9, bagging_freq=2, boosting_type='gbdt',
#               class_weight=None, colsample_bytree=1.0, feature_fraction=1.0,
#               importance_type='split', learning_rate=0.2, max_depth=-1,
#               min_child_samples=86, min_child_weight=0.001, min_split_gain=0.1,
#               n_estimators=200, n_jobs=-1, num_leaves=70, objective=None,
#               random_state=1552, reg_alpha=0.15, reg_lambda=1e-07,
#               silent='warn', subsample=1.0, subsample_for_bin=200000,
#               subsample_freq=0)
